# %%
import geopandas as gpd

# %%
level_of_service = gpd.read_file("level_of_service_streets.gpkg")
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 level_of_service = gpd.read_file("level_of_service_streets.gpkg")
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
level_of_service.columns
# Out:
# Index(['u', 'v', 'key', 'service', 'area', 'changed_u', 'tunnel', 'name',
#        'lanes', 'junction', 'ref', 'bridge', 'maxspeed', 'reversed', 'oneway',
#        'osmid_group_v', 'changed_v', 'osmid_group_u', 'width', 'highway',
#        'access', 'osmid', 'length', 'accessibility', 'geometry'],
#       dtype='object')

# %%
level_of_service.plot(column = "accessibility")
# Out:
# <Axes: >

# %%
streets = gpd.read_file("streets.gpkg")
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 streets = gpd.read_file("streets.gpkg")
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
streets.columns
# Out:
# Index(['u', 'v', 'key', 'service', 'area', 'changed_u', 'tunnel', 'lanes',
#        'name', 'junction', 'ref', 'bridge', 'maxspeed', 'reversed', 'oneway',
#        'osmid_group_v', 'changed_v', 'osmid_group_u', 'width', 'highway',
#        'access', 'osmid', 'length', 'geometry'],
#       dtype='object')

# %%
streets.plot()
# Out:
# <Axes: >

# %%
population = gpd.read_file("population.gpkg")

# %%
population.columns
# Out:
# Index(['h3_cell', 'accessibility', 'population', 'geometry'], dtype='object')

# %%
population.plot(column = "accessibility")
# Out:
# <Axes: >

# %%
print(population.iloc[20].geometry)
# Out:
# POLYGON ((386205.70222077495 4709984.78833985, 386190.8110011808 4709910.056656621, 386245.5994541242 4709864.132726736, 386315.2795370213 4709892.940909637, 386330.1706263394 4709967.673147141, 386275.38176303473 4710013.596647459, 386205.70222077495 4709984.78833985))
